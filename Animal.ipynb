# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from tensorflow import keras
from keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras.preprocessing import image
import matplotlib.pyplot as plt


import os
import matplotlib.image as mpimg

from PIL import Image

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from zipfile import ZipFile

data_path = r"C:\Users\Pranali\OneDrive\Desktop\image\animal.zip"

with ZipFile(data_path, 'r') as zip:
	zip.extractall()
	print('The data set has been extracted.')
# Out:
# The data set has been extracted.

# %%
path = r"C:\Users\Pranali\OneDrive\Desktop\image\buffalo"
classes = os.listdir(path)
classes
# Out:
# ['001.jpg',
#  '001.txt',
#  '002.jpg',
#  '002.txt',
#  '003.jpg',
#  '003.txt',
#  '004.jpg',
#  '004.txt',
#  '005.jpg',
#  '005.txt',
#  '006.jpg',
#  '006.txt',
#  '007.jpg',
#  '007.txt',
#  '008.jpg',
#  '008.txt',
#  '009.jpg',
#  '009.txt',
#  '010.jpg',
#  '010.txt',
#  '011.jpg',
#  '011.txt',
#  '012.jpg',
#  '012.txt',
#  '013.jpg',
#  '013.txt',
#  '014.jpg',
#  '014.txt',
#  '015.jpg',
#  '015.txt',
#  '016.jpg',
#  '016.txt',
#  '017.jpg',
#  '017.txt',
#  '018.jpg',
#  '018.txt',
#  '019.jpg',
#  '019.txt',
#  '020.jpg',
#  '020.txt',
#  '021.jpg',
#  '021.txt',
#  '022.jpg',
#  '022.txt',
#  '023.jpg',
#  '023.txt',
#  '024.jpg',
#  '024.txt',
#  '025.jpg',
#  '025.txt',
#  '026.jpg',
#  '026.txt',
#  '027.jpg',
#  '027.txt',
#  '028.jpg',
#  '028.txt',
#  '029.jpg',
#  '029.txt',
#  '030.jpg',
#  '030.txt',
#  '031.jpg',
#  '031.txt',
#  '032.jpg',
#  '032.txt',
#  '033.jpg',
#  '033.txt',
#  '034.jpg',
#  '034.txt',
#  '035.jpg',
#  '035.txt',
#  '036.jpg',
# ...

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

fig = plt.gcf()
fig.set_size_inches(16, 16)

buffalo_dir = r'C:\Users\Pranali\OneDrive\Desktop\image\buffalo'
# elephant_dir = r'C:\Users\Pranali\OneDrive\Desktop\image\zebra'

buffalo_names = os.listdir(buffalo_dir)
# elephant_names = os.listdir(elephant_dir)

pic_index = 210

buffalo_images = [os.path.join(buffalo_dir, fname)
                  for fname in buffalo_names[pic_index - 8:pic_index]]
# elephant_images = [os.path.join(elephant_dir, fname)
#                    for fname in elephant_names[pic_index - 9:pic_index]]

for i, img_path in enumerate(buffalo_images):  # Only using buffalo_images here, since elephant_names and elephant_dir are not defined
    sp = plt.subplot(4, 4, i + 1)
    sp.axis('Off')

    img = Image.open(img_path)
    plt.imshow(img)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[44], line 25
#      22     sp = plt.subplot(4, 4, i + 1)
#      23     sp.axis('Off')
# ---> 25     img = Image.open(img_path)
#      26     plt.imshow(img)
#      28 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3280, in open(fp, mode, formats)
#    3278     warnings.warn(message)
#    3279 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3280 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file 'C:\\Users\\Pranali\\OneDrive\\Desktop\\image\\buffalo\\102.txt'

# %%
test_image = image.load_img(r"C:\Users\Pranali\OneDrive\Desktop\image\buffalo\001.jpg", target_size=(200, 200))

# For displaying the image
plt.imshow(test_image)

# %%
test_image = image.load_img(r"C:\Users\Pranali\OneDrive\Desktop\image\buffalo\002.jpg", target_size=(200, 200))

# For displaying the image
plt.imshow(test_image)

# %%
test_image = image.load_img(r"C:\Users\Pranali\OneDrive\Desktop\image\buffalo\005.jpg", target_size=(200, 200))

# For displaying the image
plt.imshow(test_image)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
  
    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dense(512, activation='relu'),
    Dropout(0.1),
    BatchNormalization(),
    Dense(512, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 99, 99, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 23, 23, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense_6 (Dense)             (None, 512)               3277312
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dense_7 (Dense)             (None, 512)               262656
#
# ...

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
test_image = image.load_img(r'C:\Users\Pranali\OneDrive\Desktop\image\buffalo\001.jpg', target_size=(200, 200))
  
# For show image
plt.imshow(test_image)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
  
# Result array
result = model.predict(test_image)
# Mapping result array with the main name list
i = 0
if(result >= 0.5):
    print("Dog")
else:
    print("buffalo")
# Out:
# 1/1 [==============================] - 0s 64ms/step
# buffalo
